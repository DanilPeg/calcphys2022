# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your github nickname below:

# %%
NICKNAME = "DanilPeg"

# %% [markdown]
# ---

# %% [markdown]
# # Часть 1. Гауссовы квадратуры
#
# Метод Гауссовых квадратур является одним из методов численного интегрирования, который позволяет увеличить точность интегрирования, используя ортогональные полиномы и их корни в качестве узлов.
#
# $$
# \int_a^b \!  w(x)\, f(x)\, dx \approx \sum_{k=1}^n w_k \, f(x_k) \;,
# $$
#
# здесь $\omega$ - функция весов, которая определят базис ортогональных полиномов, чьи корни используются в качестве узлов интегрирования.
#
# Получаемая таким образом квадратурная схема *точно* инегрирует $f(x)$ если это полином степени $m\le2n-1$, где $n$ - степень полинома, корни которого используются в качестве узлов.

# %% [markdown]
# ## Двухточечная квадратура Гаусса
#
# Постройте квадратурную формулу Гаусса, интегрирующую точно многочлены степеней вплоть до третьей на интервале $[a, b]$. Заметим, что для этого достаточно построить _двухточечную_ квадратуру.
#
#     hint:Легко найти точки и веса для отрезка [-1,1], после чего можно сделать аффинное преобразование..
#
# Напишите функцию, которая возвращает веса, $w_1$ и $w_2$, и узлы, $x_1$ и $x_2$, двухточечной квадратурной формулы Гаусса с весовой функцией $w(x) = 1$, т.е., интегралы вида
#
# $$
# \int_a^b\! f(x)\, dx \approx w_1 f(x_1) + w_2 f(x_2)
# $$

# %%
import scipy.special
def gauss_2(a, b):
    r"""Return nodes and weights for a two-point Gauss quadrature on [a, b].
    
    Parameters
    ----------
    a, b : float
       Boundaries of the integration interval
       
    Returns
    -------
    x1, x2, w1, w2 : float
       Nodes and weights of the quadrature.
    """
    ns, ws = scipy.special.roots_legendre(2)
    x1, x2 = (a+b)/2+(b-a)/2 * ns[0], (a+b)/2+(b-a)/2 * ns[1]
    w1, w2 = (b-a)/2 * ws[0], (b-a)/2 * ws[1]
    return x1, x2, w1, w2

# %%
from numpy.testing import assert_allclose

x1, x2, w1, w2 = gauss_2(0, 1)

def f(x, n): 
    return x**n

for n in [0, 1, 2, 3]:
    assert_allclose(w1*f(x1, n=n) + w2*f(x2, n=n),
                    1./(n+1), atol=1e-14)

# %% [markdown]
# ## Использование ортогональных полиномов

# %% [markdown]
# ### Legendre

# %% [markdown]
# Теперь посчитаем следующий интеграл:
#
# $$
# \int_{-1}^1 (7x^3 - 8 x^2 - 3 x + 3) dx  \label{eq1}\tag{1}
# $$
#
# Здесь функция уже полиномиальна, поэтому возьмем весовую функцию $\omega(x) = 1$. Тогда вычисление интеграла сводится к сумме корней полинома, соответствующих весовой функции $\omega(x) = 1$. Например, здесь https://dlmf.nist.gov/18.3 вы можете увидеть, какой базис полиномов соответствует вашей весовой функции.
#
# Заметим, что нашей соответствуют полиномы Лежандра. Теперь, зайдем в документацию https://docs.scipy.org/doc/scipy/reference/special.html#orthogonal-polynomials. Функция *roots_legendre* сразу же выдаст корни полиномов Лежандра, а также веса к их корням (для полиномов Лежандра все эти веса равны единице).

# %% [markdown]
# 1. Посчитайте точное значение интеграла ([1](#mjx-eqn-eq1)) "руками".

# %%
Integral = 2/3
print(Integral)
# Out:
# 0.6666666666666666

# %% [markdown]
# 2. Посчитайте значение интеграла ([1](#mjx-eqn-eq1)), используя обычный метод интегрирования на равномерной сетке (например, написанный вами в предыдущем дз). Оцените количество узлов, необходимых для достижения относительной точности $10^{-10}$.

# %%
import numpy as np

# %%
def midpoint_rule(func, a, b, eps):
    
    I = float('inf')
    i = 0
    N = 2
    
    while i == 0:
        
        hk = (b-a)/N
        xk = np.linspace(a + hk/2, b - hk/2, N)
        Qk = [func(k) for k in xk]
        Q = np.sum(Qk)*hk
        
        if (abs(I-Q)<eps):
            break
            
        N *= 2
        I = Q
        
    return Q, N
func = lambda x: 7*x**3 - 8*x**2 - 3*x + 3
I, N = midpoint_rule(func, -1, 1, 1e-10)
print("I =", I, ", число узлов", N+1)
# Out:
# I = 0.6666666666860692 , число узлов 524289

# %% [markdown]
# 3. Посчитайте значение интеграла ([1](#mjx-eqn-eq1)), с помощью Гауссовой квадратуры (используя корни полинома Лежандра степени от 1 до 6 в качестве узлов) (чтобы получить корни и веса используйте scipy.special.roots_legendre)

# %%
from scipy.special import roots_legendre

# %%
def legendre_nodes_method(n, func): #n - степень полинома Лежандра
    
    x, w = roots_legendre(n)
    
    return np.sum(func(x)*w)
for i in range(1,7):
    print("I =", legendre_nodes_method(i, func), ", число узлов:", i)
# Out:
# I = 6.0 , число узлов: 1
# I = 0.6666666666666674 , число узлов: 2
# I = 0.6666666666666639 , число узлов: 3
# I = 0.6666666666666667 , число узлов: 4
# I = 0.6666666666666685 , число узлов: 5
# I = 0.6666666666666695 , число узлов: 6

# %% [markdown]
# Сравните количество узлов, необходимых для достижения одинаковой точности в обоих чисенных методах.

# %% [markdown]
# Для корней полинома Лежандра нужно значительно меньше (6 против 524к) узлов для получения сравнимой точности.

# %% [markdown]
# Вычислите значение того же интеграла, но на интервале от 0 до 10.
#
# $$
# \int_{0}^{10} (7x^3 - 8 x^2 - 3 x + 3) dx
# $$
#
# Заметим, что больше нельзя использовать полиномы Лежанда, потому что они определены на интервале (-1, 1). Однако всегда можно произвести *аффинное преобразование* для того, чтобы перейти к желаемой системе координат.
#
# (20% итоговой оценки)

# %%
a_func = lambda x: 5*(7*125*(x+1)**3 - 8*25*(x+1)**2 - 15*(x+1) + 3)
for i in range(1,7):
    print("I =", legendre_nodes_method(i, a_func), ", число узлов:", i)
# Out:
# I = 6630.0 , число узлов: 1
# I = 14713.333333333332 , число узлов: 2
# I = 14713.333333333336 , число узлов: 3
# I = 14713.333333333332 , число узлов: 4
# I = 14713.333333333328 , число узлов: 5
# I = 14713.33333333333 , число узлов: 6

# %% [markdown]
# Сравните результат с точным значением интеграла.

# %%
Integral = 44140/3
print(Integral)
# Out:
# 14713.333333333334

# %%
Integral - legendre_nodes_method(2, a_func)
# Out:
# 1.8189894035458565e-12

# %% [markdown]
# ###
#
# Вычислите значение следующиего интеграла:
# $$
# \int_{0}^{2\pi} \frac{cos(x) dx }{\sqrt{4\pi^2 - x^2}}
# $$
# используя соответствующий базис ортогональных полиномов.
# Найдите степень полинома (количество узлов), при которой точность превысит машинное $\epsilon$.

# %%
from scipy.special import roots_chebyt
def chebyt_nodes_method(n, func): #n - степень полинома Лежандра
    
    x, w = roots_chebyt(n)
    
    return np.sum(func(x)*w)
f = lambda x: np.cos(2*np.pi*x)/2
I = float('inf')
n = 1
while 0 == 0:
    i = chebyt_nodes_method(n, f)
    if I-i == 0:
        break
    I = i
    n +=1
print("I =", I, ", число узлов:", n-1)
# Out:
# I = 0.34601015881226443 , число узлов: 16

# %% [markdown]
# # Часть 2. Уравение Фредгольма
#
# Существует два типа уравнений Фредгольма:
#
# 1. Уравение Фредгольма первого рода:
# $$
# \int_a^b \! K(x, t)\, \color{blue}{f(t)} \,dt = g(x)
# $$
#
# 2. Уравнение Фредгольма второго рода:
# $$
# \lambda \int_a^b\! K(x, t)\, \color{blue}{f(t)} \, dt + g(x) = \color{blue}{f(x)}
# $$
#
# Здесь функция $f(x)$ неизвестна, $K(x, t)$ - ядро уравнения, заданная функция $g(x)$ и $\lambda$ - рациональное число.
# С точки зрения вычислений, уравение Фредгольма первого рода крайне неустойчиво. Далее мы рассмотрим только уравнение второго рода.

# %% [markdown]
# Основная идея - аппроксимировать интеграл некой квадратурной формулой
#
# $$
# \int_a^b \! \xi(t)\, dt \approx \sum_j^N w_j\, \xi(t_j)
# $$
#
# с подходящими весами $w_j$ и узлами $t_j$, $j=1, \dots, N$. Точность аппроксимации контролируется $N$.

# %% [markdown]
# Таким образом, уравнение Фредгольма приближается следующим образом:
#
# $$
# \lambda \sum_j w_j\, K(x, t_j)\, \color{blue}{f(t_j)} + g(x) = \color{blue}{f(x)}
# $$
#
# Отметим, что $x$ - непрерывная переменная, в то время, как $t$ - дискретная.

# %% [markdown]
# Рассматривая данное уравнение на тех же узлах сетки $x = t_k$, получаем
#
# $$
# \lambda \sum_j w_j \, K_{k, j}\, \color{blue}{f_j} + g_k = \color{blue}{f_k}
# $$
#
# где $f_j \equiv f(t_j)$, $g_j \equiv g(t_j)$ and $K_{k, j} \equiv K(t_k, t_j)$. Это ничто иное, как система линейных алгебраических уравнений на вектор $\color{blue}{f_j}$.
#
# Ее решение выдает значение неизвестной функции $f(x)$ в дискретных точках $x=t_j$ для $j=1, \dots, N$.

# %% [markdown]
# Решите предложенное уравнение Фредгольма второго рода
#
# $$
# f(x) = \cos(x)  + \frac{1}{2\pi} \int_0^\pi \! \sin(x) \,t f(t) \, dt
# $$
#
# Здесь $a, b = 0, 1$, $\lambda = \dfrac{1}{2\pi}$, ядро $K(x, t) = \sin(x)\cdot t$ и правая часть - $g(x) = \cos(x)$.
#
# Точное решение (Сборник задач по интегральным уравнениям, 2006):
#
# $$
# f(x) = \cos(x)- \frac{2}{\pi}\sin(x)
# $$

# %% [markdown]
# Для нахождения интеграла преобразуйте заменой переменных в интеграле область интегрирования в [0,1] воспользуйтесь Гауссовой квадратурой с весовой функцией $w(x) = 1$ на $(0, 1)$. Посмотрите на http://dlmf.nist.gov/18.3, и найдите соответствующую функцию в *scipy.special* (обратите внимание на область интегрирования).
#
# Напишите функцию, возвращающую значение f(t_j) по схеме выше, которая в качестве параметра принимает величину $N$--число узлов в квадратуре, для нахождение решения СЛАУ можно использовать `scipy.linalg.solve`.
#
# Постройте график истинного решения и набор (t_j, f_j) для раличных $N$, используя вашу функцию.

# %%
from scipy.linalg import solve as lg
fr = lambda x: np.cos(x) - (2/np.pi) * np.sin(x)
x_lin = np.linspace(0, np.pi, 100)
def Shifted_Legendre(N):
    roots, weights = scipy.special.roots_sh_legendre(N)
    I_ = np.eye(N)
    A = np.vectorize(lambda x, t: np.sin(np.pi * x) * t)
    A_ = np.pi * 0.5 * np.array([weights * A(t, roots) for t in roots]) - I_
    g = lambda x: np.cos(np.pi * x)
    g_ = - g(roots)
    f_ = lg(A_, g_)
    return f_, roots, weights



N_ = [14, 4, 2]
for N in N_:

    f_, roots, _ = Shifted_Legendre(N)
    x = roots * np.pi
    plt.plot(x, f_, label=('$N = %s$' % N), zorder=N, linewidth=1.5)
    
plt.plot(x_lin, fr(x_lin), '--', dashes=(2,6), linewidth=1, zorder=20, label='$Exact~~solution$', color='black')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# The degree: 1   the error: 1.1827943391437856
# The degree: 2   the error: 1.6192083901190726
# The degree: 3   the error: 1.9826826467472647
# The degree: 4   the error: 2.2890577024395906
# The degree: 5   the error: 2.5590327473749364
# The degree: 6   the error: 2.803133538298571
# The degree: 7   the error: 3.02762125333629
# The degree: 8   the error: 3.2365780210291137
# The degree: 9   the error: 3.4328403803956973
# The degree: 10   the error: 3.6184741185133635
# The degree: 11   the error: 3.795039015590915
# The degree: 12   the error: 3.963747026113704
# The degree: 13   the error: 4.125562052256699
# The degree: 14   the error: 4.281265685532734
# The degree: 15   the error: 4.431502111821901
# The degree: 16   the error: 4.576809724042392
# The degree: 17   the error: 4.717643956650197
# The degree: 18   the error: 4.854394149082904
# The degree: 19   the error: 4.987396242331142
# The degree: 20   the error: 5.116942501923539
# The degree: 21   the error: 5.243289076632237
# The degree: 22   the error: 5.3666619541032805
# The degree: 23   the error: 5.487261710340389
# The degree: 24   the error: 5.605267338799944
# The degree: 25   the error: 5.720839368133541
# The degree: 26   the error: 5.834122423722007
# The degree: 27   the error: 5.945247349674788
# The degree: 28   the error: 6.054332980102976
# The degree: 29   the error: 6.161487628016094
# The degree: 30   the error: 6.266810344987643
# The degree: 31   the error: 6.370391993303091
# The degree: 32   the error: 6.472316163619321
# The degree: 33   the error: 6.572659964502006
# The degree: 34   the error: 6.671494705048406
# The degree: 35   the error: 6.768886487775527
# The degree: 36   the error: 6.864896725783208
# The degree: 37   the error: 6.959582595688005
# The degree: 38   the error: 7.05299743581643
# The degree: 39   the error: 7.145191097532733
# The degree: 40   the error: 7.236210256271476
# The degree: 41   the error: 7.326098687783562
# The degree: 42   the error: 7.414897514235892
# The degree: 43   the error: 7.502645424090682
# The degree: 44   the error: 7.58937886909994
# The degree: 45   the error: 7.67513224126081
# The degree: 46   the error: 7.759938032168085
# The degree: 47   the error: 7.843826976858091
# The degree: 48   the error: 7.926828183949625
# The degree: 49   the error: 8.008969253644452
# The degree: 50   the error: 8.09027638494351
# The degree: 51   the error: 8.170774473259584
# The degree: 52   the error: 8.250487199457279
# The degree: 53   the error: 8.32943711122288
# The degree: 54   the error: 8.407645697556616
# The degree: 55   the error: 8.48513345708467
# The degree: 56   the error: 8.561919960806307
# The degree: 57   the error: 8.638023909820399
# The degree: 58   the error: 8.713463188513737
# The degree: 59   the error: 8.788254913639726
# The degree: 60   the error: 8.862415479669007
# The degree: 61   the error: 8.935960600752457
# The degree: 62   the error: 9.008905349600678
# The degree: 63   the error: 9.081264193552624
# The degree: 64   the error: 9.153051028077693
# The degree: 65   the error: 9.224279207931067
# The degree: 66   the error: 9.294961576160201
# The degree: 67   the error: 9.365110491140786
# The degree: 68   the error: 9.434737851803439
# The degree: 69   the error: 9.503855121196892
# The degree: 70   the error: 9.572473348519841
# The degree: 71   the error: 9.640603189741391
# The degree: 72   the error: 9.708254926918956
# The degree: 73   the error: 9.775438486312968
# The degree: 74   the error: 9.842163455388512
# The degree: 75   the error: 9.90843909878655
# The degree: 76   the error: 9.974274373339952
# The degree: 77   the error: 10.039677942203255
# The degree: 78   the error: 10.10465818815925
# The degree: 79   the error: 10.169223226160307
# The degree: 80   the error: 10.2333809151575
# The degree: 81   the error: 10.297138869266403
# The degree: 82   the error: 10.360504468314303
# The degree: 83   the error: 10.42348486781052
# The degree: 84   the error: 10.486087008377607
# The degree: 85   the error: 10.548317624678822
# The degree: 86   the error: 10.610183253874295
# The degree: 87   the error: 10.671690243636059
# The degree: 88   the error: 10.732844759749577
# The degree: 89   the error: 10.79365279332766
# The degree: 90   the error: 10.854120167660723
# The degree: 91   the error: 10.914252544725317
# The degree: 92   the error: 10.974055431371738
# The degree: 93   the error: 11.033534185209875
# The degree: 94   the error: 11.092694020210828
# The degree: 95   the error: 11.15154001204125
# The degree: 96   the error: 11.210077103145474
# The degree: 97   the error: 11.268310107590223
# The degree: 98   the error: 11.326243715684964
# The degree: 99   the error: 11.383882498390689
# The degree: 100   the error: 11.441230911528894
# The degree: 101   the error: 11.498293299801412
# The degree: 102   the error: 11.555073900631731
# The degree: 103   the error: 11.611576847837291
# The degree: 104   the error: 11.667806175141573
# The degree: 105   the error: 11.723765819534634
# The degree: 106   the error: 11.77945962449001
# The degree: 107   the error: 11.834891343045413
# The degree: 108   the error: 11.890064640753916
# The degree: 109   the error: 11.944983098512806
# The degree: 110   the error: 11.999650215275553
# The degree: 111   the error: 12.054069410653424
# The degree: 112   the error: 12.108244027411528
# The degree: 113   the error: 12.16217733386517
# The degree: 114   the error: 12.215872526180553
# The degree: 115   the error: 12.269332730585212
# The degree: 116   the error: 12.322561005491965
# The degree: 117   the error: 12.37556034354072
# The degree: 118   the error: 12.42833367356183
# The degree: 119   the error: 12.480883862464744
# The degree: 120   the error: 12.533213717055594
# The degree: 121   the error: 12.585325985786406
# The degree: 122   the error: 12.637223360439682
# The degree: 123   the error: 12.688908477750822
# The degree: 124   the error: 12.740383920971365
# The degree: 125   the error: 12.791652221375568
# The degree: 126   the error: 12.842715859712962
# The degree: 127   the error: 12.89357726760904
# The degree: 128   the error: 12.944238828916275
# The degree: 129   the error: 12.994702881018167
# The degree: 130   the error: 13.044971716087309
# The degree: 131   the error: 13.095047582300515
# The degree: 132   the error: 13.144932685011915
# The degree: 133   the error: 13.194629187886317
# The degree: 134   the error: 13.244139213994297
# The degree: 135   the error: 13.293464846870425
# The degree: 136   the error: 13.342608131536537
# The degree: 137   the error: 13.391571075490909
# The degree: 138   the error: 13.440355649665205
# The degree: 139   the error: 13.488963789350276
# The degree: 140   the error: 13.537397395092027
# The degree: 141   the error: 13.58565833355825
# The degree: 142   the error: 13.633748438378412
# The degree: 143   the error: 13.681669510956365
# The degree: 144   the error: 13.72942332125772
# The degree: 145   the error: 13.777011608572746
# The degree: 146   the error: 13.824436082255508
# The degree: 147   the error: 13.871698422440158
# The degree: 148   the error: 13.918800280735741
# The degree: 149   the error: 13.965743280899364
# The degree: 150   the error: 14.012529019489529
# The degree: 151   the error: 14.059159066499648
# The degree: 152   the error: 14.10563496597281
# The degree: 153   the error: 14.151958236598274
# The degree: 154   the error: 14.198130372290588
# The degree: 155   the error: 14.244152842751733
# The degree: 156   the error: 14.290027094016915
# The degree: 157   the error: 14.335754548984774
# The degree: 158   the error: 14.381336607932372
# The degree: 159   the error: 14.426774649015462
# The degree: 160   the error: 14.472070028754558
# The degree: 161   the error: 14.517224082507854
# The degree: 162   the error: 14.562238124930031
# The degree: 163   the error: 14.607113450419266
# The degree: 164   the error: 14.65185133355146
# The degree: 165   the error: 14.696453029502427
# The degree: 166   the error: 14.74091977445919
# The degree: 167   the error: 14.785252786019116
# The degree: 168   the error: 14.829453263579625
# The degree: 169   the error: 14.873522388716372
# The degree: 170   the error: 14.91746132555193
# The degree: 171   the error: 14.961271221114524
# The degree: 172   the error: 15.004953205687505
# The degree: 173   the error: 15.04850839314952
# The degree: 174   the error: 15.091937881305851
# The degree: 175   the error: 15.135242752211589
# The degree: 176   the error: 15.178424072485646
# The degree: 177   the error: 15.221482893617909
# The degree: 178   the error: 15.264420252267414
# The degree: 179   the error: 15.307237170553993
# The degree: 180   the error: 15.34993465634187
# The degree: 181   the error: 15.392513703516755
# The degree: 182   the error: 15.43497529225535
# The degree: 183   the error: 15.477320389289142
# The degree: 184   the error: 15.51954994816067
# The degree: 185   the error: 15.561664909474544
# The degree: 186   the error: 15.603666201141644
# The degree: 187   the error: 15.645554738617548
# The degree: 188   the error: 15.687331425135676
# The degree: 189   the error: 15.728997151934172
# The degree: 190   the error: 15.770552798478018
# The degree: 191   the error: 15.811999232675456
# The degree: 192   the error: 15.85333731108954
# The degree: 193   the error: 15.894567879144716
# The degree: 194   the error: 15.935691771328578
# The degree: 195   the error: 15.976709811388604
# The degree: 196   the error: 16.017622812525364
# The degree: 197   the error: 16.058431577579885
# The degree: 198   the error: 16.09913689921796
# The degree: 199   the error: 16.139739560109476
# The degree: 200   the error: 16.180240333104262
# The degree: 201   the error: 16.220639981403547
# The degree: 202   the error: 16.26093925872788
# The degree: 203   the error: 16.30113890948108
# The degree: 204   the error: 16.34123966891071
# The degree: 205   the error: 16.38124226326505
# The degree: 206   the error: 16.42114740994654
# The degree: 207   the error: 16.460955817661713
# The degree: 208   the error: 16.50066818656829
# The degree: 209   the error: 16.540285208418773
# The degree: 210   the error: 16.579807566700918
# The degree: 211   the error: 16.619235936775553
# The degree: 212   the error: 16.658570986011046
# The degree: 213   the error: 16.69781337391507
# The degree: 214   the error: 16.7369637522638
# The degree: 215   the error: 16.776022765228035
# The degree: 216   the error: 16.814991049496868
# The degree: 217   the error: 16.853869234399088
# The degree: 218   the error: 16.892657942021255
# The degree: 219   the error: 16.931357787324213
# The degree: 220   the error: 16.96996937825679
# The degree: 221   the error: 17.008493315867025
# The degree: 222   the error: 17.04693019441161
# The degree: 223   the error: 17.085280601462575
# The degree: 224   the error: 17.12354511801234
# The degree: 225   the error: 17.161724318576244
# The degree: 226   the error: 17.19981877129317
# The degree: 227   the error: 17.23782903802419
# The degree: 228   the error: 17.275755674449588
# The degree: 229   the error: 17.313599230163028
# The degree: 230   the error: 17.351360248764916
# The degree: 231   the error: 17.389039267953542
# The degree: 232   the error: 17.426636819614
# The degree: 233   the error: 17.464153429906244
# The degree: 234   the error: 17.501589619350735
# The degree: 235   the error: 17.538945902912772
# The degree: 236   the error: 17.5762227900852
# The degree: 237   the error: 17.613420784969303
# The degree: 238   the error: 17.650540386354514
# The degree: 239   the error: 17.687582087796393
# The degree: 240   the error: 17.72454637769334
# The degree: 241   the error: 17.761433739361316
# The degree: 242   the error: 17.798244651108018
# The degree: 243   the error: 17.83497958630508
# The degree: 244   the error: 17.87163901345891
# The degree: 245   the error: 17.908223396280828
# The degree: 246   the error: 17.944733193755024
# The degree: 247   the error: 17.98116886020607
# The degree: 248   the error: 18.0175308453647
# The degree: 249   the error: 18.053819594432806
# The degree: 250   the error: 18.09003554814674
# The degree: 251   the error: 18.12617914283991
# The degree: 252   the error: 18.162250810504265
# The degree: 253   the error: 18.19825097885011
# The degree: 254   the error: 18.23418007136583
# The degree: 255   the error: 18.27003850737551
# The degree: 256   the error: 18.30582670209647
# The degree: 257   the error: 18.341545066694998
# The degree: 258   the error: 18.37719400834166
# The degree: 259   the error: 18.412773930265296
# The degree: 260   the error: 18.4482852318065
# The degree: 261   the error: 18.48372830846966
# The degree: 262   the error: 18.5191035519745
# The degree: 263   the error: 18.55441135030649
# The degree: 264   the error: 18.589652087766705
# The degree: 265   the error: 18.624826145020045
# The degree: 266   the error: 18.659933899144132
# The degree: 267   the error: 18.69497572367564
# The degree: 268   the error: 18.72995198865711
# The degree: 269   the error: 18.764863060682387
# The degree: 270   the error: 18.799709302941544
# The degree: 271   the error: 18.834491075264857
# The degree: 272   the error: 18.86920873416615
# The degree: 273   the error: 18.903862632885584
# The degree: 274   the error: 18.938453121431507
# The degree: 275   the error: 18.972980546621564
# The degree: 276   the error: 19.0074452521235
# The degree: 277   the error: 19.041847578494956
# The degree: 278   the error: 19.076187863222504
# The degree: 279   the error: 19.110466440760895
# The degree: 280   the error: 19.1446836425704
# The degree: 281   the error: 19.178839797154524
# The degree: 282   the error: 19.21293523009671
# The degree: 283   the error: 19.24697026409662
# The degree: 284   the error: 19.280945219006057
# The degree: 285   the error: 19.31486041186289
# The degree: 286   the error: 19.34871615692743
# The degree: 287   the error: 19.38251276571464
# The degree: 288   the error: 19.41625054702846
# The degree: 289   the error: 19.449929806994838
# The degree: 290   the error: 19.48355084909353
# The degree: 291   the error: 19.51711397419066
# The degree: 292   the error: 19.550619480569534
# The degree: 293   the error: 19.584067663962017
# The degree: 294   the error: 19.617458817578843
# The degree: 295   the error: 19.650793232139478
# The degree: 296   the error: 19.68407119590191
# The degree: 297   the error: 19.717292994691505
# The degree: 298   the error: 19.750458911929535
# The degree: 299   the error: 19.78356922866188
# The degree: 300   the error: 19.816624223586313
# The degree: 301   the error: 19.84962417308014
# The degree: 302   the error: 19.882569351227268
# The degree: 303   the error: 19.9154600298442
# The degree: 304   the error: 19.94829647850686
# The degree: 305   the error: 19.981078964576056
# The degree: 306   the error: 20.013807753222817
# The degree: 307   the error: 20.046483107453586
# The degree: 308   the error: 20.0791052881349
# The degree: 309   the error: 20.11167455401732
# The degree: 310   the error: 20.144191161760084
# The degree: 311   the error: 20.17665536595385
# The degree: 312   the error: 20.20906741914466
# The degree: 313   the error: 20.241427571856402
# The degree: 314   the error: 20.27373607261384
# The degree: 315   the error: 20.305993167964193
# The degree: 316   the error: 20.338199102499782
# The degree: 317   the error: 20.37035411887952
# The degree: 318   the error: 20.402458457850013
# The degree: 319   the error: 20.434512358266502
# The degree: 320   the error: 20.466516057113907
# The degree: 321   the error: 20.498469789527366
# The degree: 322   the error: 20.530373788812092
# The degree: 323   the error: 20.56222828646311
# The degree: 324   the error: 20.59403351218513
# The degree: 325   the error: 20.62578969391216
# The degree: 326   the error: 20.657497057825847
# The degree: 327   the error: 20.689155828374922
# The degree: 328   the error: 20.720766228293137
# The degree: 329   the error: 20.75232847861813
# The degree: 330   the error: 20.783842798709227
# The degree: 331   the error: 20.81530940626513
# The degree: 332   the error: 20.84672851734145
# The degree: 333   the error: 20.878100346368317
# The degree: 334   the error: 20.90942510616688
# The degree: 335   the error: 20.940703007966913
# The degree: 336   the error: 20.971934261422927
# The degree: 337   the error: 21.003119074630494
# The degree: 338   the error: 21.034257654142756
# The degree: 339   the error: 21.065350204986096
# The degree: 340   the error: 21.096396930676196
# The degree: 341   the error: 21.12739803323331
# The degree: 342   the error: 21.158353713197563
# The degree: 343   the error: 21.18926416964455
# The degree: 344   the error: 21.220129600199737
# The degree:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       6 f = np.linalg.solve(A(n,x), g(x))
#       7 error = np.linalg.norm(func(x) - f)
# ----> 8 print("The degree:", n, "  the error:", error)
#       9 if  error < 1e-16:
#      10     break
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
#     214     self._events.append(f)
#     215     # wake event thread (message content is ignored)
# --> 216     self._event_pipe.send(b'')
#     217 else:
#     218     f()
#
# File ~\anaconda3\lib\site-packages\zmq\sugar\socket.py:547, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     540         data = zmq.Frame(
#     541             data,
#     542             track=track,
#     543             copy=copy or None,
#     544             copy_threshold=self.copy_threshold,
#     545         )
#     546     data.group = group
# --> 547 return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:718, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:765, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# Очевидной проблемой предыдущего результата для $f(x)$ является то, что он возвращает решения на фиксированном наборе точек. Мы не контролируем их расположение.
#
# Оказывается, интерполяционные методы (мы обсудим их на следующих занятиях) работают не очень хорошо, в сравнении с следующим подходом:

# %% [markdown]
# Используйте изначальный вид, чтобы вычислить значение функции на всём интервале:
#
# $$
# f(x) = g(x) + \lambda \sum_j^N w_j\, K(x, t_j)\, f(t_j)
# $$
#
# Сравните эту интерполяцию с точным решением для разлиных $N$.
# (выбирайте наглядный масштаб)

# %%
x_lin = np.linspace(0, np.pi, 77)
K = np.vectorize(lambda x, t: np.sin(np.pi * x) * t)
g = lambda x: np.cos(np.pi * x)

N_ = [3, 2]
for N in N_:
    f_unity, roots, weights = Shifted_Legendre(N)

    func = lambda x: g(x) + 0.5 * np.pi * (weights * K(x, roots) * f_unity).sum()
    f_lin = np.array([func(x) for x in x_lin/np.pi])
    plt.plot(x_lin, f_lin, label=('$N = %s$' % N), zorder=N, linewidth=1.5)

fr = lambda x: np.cos(x) - (2 / np.pi) * np.sin(x)


plt.plot(x_lin, fr(x_lin), '--', dashes=(2,6), linewidth=1, zorder=20, alpha=1, label='$Exact~~solution$', color='black')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Часть 3. Интеграл от осциллирующей функции - EXTRA points task
#
# Рассмотрим определенный интеграл
#
# $$
# I = \int_0^\infty\! \frac{\sin(x) \cos{(\cos{(x)})}}{x}\,dx
# $$
#
# Вычислите значение данного интеграла с относительной точностью $10^{-6}$. Для упрощения задачи можете воспользоваться функционалом `scipy.integrate.quad`.
#
# Заметим, что "из коробки" интеграл вычислить не удается, и нужно что-то придумать.

# %%
from math import sin, cos

from scipy.integrate import quad
quad(lambda x: sin(x) * cos(cos(x)) / x, 0, float('inf'))

# %% [markdown]
# Напишите функцию, которая возвращает значение данного интеграла. Только само значение интеграла, без оценки погрешности.
# (оборачиваем интеграл в функцию только для удобства автопроверки).

# %%
from scipy.integrate import quad

def integ():
    """Return a single float, the computed value of the integral."""

# %%
from numpy.testing import assert_allclose

# this is a test cell, keep it intact
